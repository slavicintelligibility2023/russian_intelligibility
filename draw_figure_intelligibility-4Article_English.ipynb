# %% [markdown]
# # Intelligibility of Slavic Languages for Russian Native Speakers
# #### Source codes and results of data analysis

# %% [markdown]
# ## INTRODUCTION
# It has long been recognized that speakers of related languages can have successful communication speaking their native languages. Various terms have been used to refer to such kind of communication like semicommunication, receptive multilingualism, semibilingualism, inherent intelligibility, non-convergent discourse, asymmetric/bilingual discourse (Gooskens, 2013).
#
# Mutual intelligibility has long been used as one of the criteria to identify whether two speech varieties should be considered dialects of the same language or two distinct languages (Gleason 1959, Comrie 1981). Knowledge about the degree to which two related languages are mutually intelligible is also required for various language planning, language policy, language contact issues.
#
# Receptive multilingualism has recently come into focus as a way of communicating across language borders, a possible alternative to using a lingua franca. Two major projects dedicated to mutual intelligibility studies need to be mentioned here.
#
# The first one, MICReLa (Mutual Intelligibility of Closely Related Languages) described in Gooskens & Swarte (2017), Gooskens et al. (2018), focuses on receptive multilingualism in Europe aiming to improve communication in the region. The project studies what factors influence mutual intercomprehension and to what extent it can be used to overcome language barriers. It follows the team’s preceding research into intelligibility between Scandinavian languages and currently covers 16 languages spoken in Europe from Germanic, Romance, and Slavic language families. Though this large-scale study provides a unified approach and an important basis for comparison of intelligibility within language families, the resulting picture of mutual intelligibility between languages is incomplete. The Slavic language family in this project is represented by the West and South Slavic languages. As we demonstrate below, the missing information on the East Slavic languages (and most importantly Russian) can help to understand why Bulgarian is the least intelligible to other Slavic languages in this study.
#
# The second major project, INCOMSLAV (Mutual Intelligibility and Surprisal in Slavic Intercomprehension, (Mosbach et al. (2019), Stenger et al. (2020b)), aims to research the relation between information density, encoding density and grammaticalisation in a cross-linguistic perspective with a focus on mutual intelligibility between Slavic languages. The project includes spoken and written intercomprehension experiments between 11 Slavic languages (including Russian) through a web-based platform. At the current stage intelligibility is tested on three levels: words, noun phrases, and sentences. Our research studies the comprehension of words in a text, which supposedly may provide additional semantic clues (other than the ones within the sentence) to facilitate the understanding of missing words in it.
#
# Our paper presents a study of written intelligibility of eight Slavic languages to native speakers of Russian. It aims to check how intelligible words of an unknown but related language can be when given in a text.
#
# Our first hypothesis was that a parallel text in an unknown Slavic language increases the correctness of answers when people fill gaps in a text in Russian. Presumably this increase should correlate with the intelligibility of the parallel text language.
#
# Our second hypothesis was that the intelligibility of a text in an unknown but related foreign language depends not only on the percentage of words in this text that are historically related with words in one’s native language and still keep their phonetic/graphic and semantic similarity with them, but also on the percentage of other categories of words such as those which look similar but have different meanings.

# %% [markdown]
# ## Experiment set-up
#
# In our experiment participants were given a text in Russian with omitted words and a parallel text in a Slavic language (unknown to them) to use as a clue. In our case, there were no restrictions on the answers other than the ones imposed by the context in Russian and the clue from a corresponding word in another Slavic language (provided the participant identified it correctly in the sentence). This way of arranging the experiment does not limit participants in their choice of words and allows gathering objective quantitative information on a text intelligibility.
#
# When choosing words to omit in the test, we selected nouns, verbs, adjectives and adverbs. It was clear that some words would be more difficult to restore than others, so we focused on making the test pieces more or less similar in the respective amount of words easier and more difficult to restore.
#
# If a word was omitted in the text once, it was to be omitted in all other occurrences in this test (so that it would not be possible to guess it in case its equivalent is repeated in the parallel text). Words (totalling 186 lemmas, 232 word occurrences) were omitted in the Russian part of a test independently from translations.
#
# Of the nine languages used in the study, five (including Russian) use Cyrillic alphabet and four use Latin alphabet. To avoid problems with the extended Latin script, we transliterated such parallel texts into Cyrillic using simple rules of substitution, like i-и, p-п, č-ч, sz-ш, szcz-щ etc (For phonetic correspondences we used [Wiktionary](https://en.wiktionary.org/wiki/Appendix:Polish_pronunciation])). For the sake of consistency all parallel texts written in Cyrillic script were transliterated into standard Latin. Thus, participants saw each parallel text written both in Latin and Cyrillic scripts (one above the other) aligned by sentences.
#
# It is possible to restore words in a gapped text using the text redundancy on the basis of limitations imposed by the context itself (Jagrova & Avgustinova (2019), Krutchenko et al. (2020), Lopukhina et al. (2021)). To separate this influence from that of a parallel language text and to create a benchmark for comparison each test piece was given to a control group of Russian native speakers to do without a parallel text in another Slavic language.
#
# All participants did tests on a website without any observation of their behaviour. At the beginning of test each participant was asked to select their level of education, to indicate if they knew any other Slavic language, and if their education included any language studies.1 This information was used to ensure that participants received a parallel text in an unknown language - all Slavic languages named by the participant were excluded from the list from which the parallel language for the test was randomly selected. It was also possible to skip these questions, then the subject was given a control test (one of the six gapped text pieces in Russian without a parallel text).
#
# In the experiment we used three pieces from M. Bulgakov’s Master and Margaret (originally written in Russian), three pieces of H. Sienkiewicz’s Quo Vadis? (originally written in Polish), and their modern translations into the other languages in the study.
#
# The pieces were as follows:
#
# Table 1. Test contents
#
# |Test №|Source|Contents|Omitted words|Total words|Sentences|
# |--|--|--|--|--|--|
# |1|Master and Margaret|Pontius Pilate is leaving the place of Yeshua's execution|42|390|16|
# |2|Master and Margaret|medical inspection of Bezdomny|39|396|23|
# |3|Quo Vadis|Vinicius is riding to the burning Rome|35|278|20|
# |4|Quo Vadis|Vinicius is thinking about the missing Ligia|44|408|20|
# |5|Quo Vadis|Vinicius is thinking about the kidnapped Ligia|37|380|23|
# |6|Master and Margaret|сonversation between Voland, Berlioz and Bezdomny|35|337|16|
#
# In our experiment the correctness of answers was evaluated according to the following scale.
# * A word from the original text or its close synonym were considered as a ‘completely correct’ answer. Such answers were assigned 1 point. In the example below such words as замкнуться ‘withdraw into oneself’, отгородиться ‘shut oneself off’ were considered completely correct.
# Поэтому Иван и от этого пути отказался, решив избрать третий: _(замкнуться)_ в гордом молчании.
# …so Ivan rejected that course too, deciding to adopt the third: he would _(wrap himself)_ in proud silence.
# * Words and their paraphrases with the same root but of a different part of speech and other words of the same part of speech which did not make the narrative illogical (i.e. words which did not render the phrase ungrammatical or make it lose sense, but the author was talking about something different there) were considered as ‘partially correct’, e.g., for the given example a noun like замкнутость ‘withdrawal’1 or such verbs as сидеть ‘sit’, замереть ‘freeze’, ждать ‘wait’ were considered ‘partially correct’. In such cases we believed that participants were close in their guess, but did not quite get the sense of the omitted word. Such answers were assigned 0.5 points.
# * A blank field, an incorrect part of speech which renders the phrase ungrammatical, and words which make the sentence illogical (i.e. make it lose sense) were considered as ‘incorrect’. For example, одиночество ‘loneliness’ was incorrect in the example above. Such answers received 0 points.

# %% [markdown]
# ## Description of Data Structure
#
# The following files are placed to the *data* folder. The first number in every file is the row id.
#
# - **user_data.csv** - participants' data. Fields description:
#     - *id_user* - identifier of a participant.
#     - *test_id* - identifier of a test passed by the participant.
#     - *parallel_lang* - a language used for a parallel text. *No Parallel Text* denotes the control group, i.e. those participants who restored words without the parallel text.
#     - *age* - age group of the participant. *sch* denotes school children, bak - bachelor students, mag - master student, fin - finished his or her education.
#     - *speciality* - the participant's education included any language studies (translation, linguistics, philology): yes - includes, no - don't includes or was not selected.
#     - *known_langs* - if the participant knows any other Slavic language. Five and more languages denote situation when the participant declined any parallel text and volonteered to be in the control group.
#     - *ans_cnt* - number of non-empty answers for this participant.
#
#
# - **user_answers.csv** - participants' answers. Fields description:
#     - *id_user* - identifier of a participant; equals to the same field in the *user_data* table.
#     - *test_id* - identifier of a test passed by the participant.
#     - *parallel_lang* - a language used for a parallel text; equals to the same field in the *user_data* table.
#     - *answer_no* - position of a omitted word in the test.
#     - *answer* - participant's answer.
#     - *correctness* - asessors' evaluation of the answer. incorr denotes an incorrect answer, pcorr - partially correct anser, corr - correct answer.
#
#
# - **texts.csv** - text phragments used as tests. The words, marked by the underscore denote omitted words in parallel texts. All texts are aligned by sentences, i.e. have the same identifier for different languages. Fields description:
#     - *id_set* - identifier of a text.
#     - *lang_name* - language of the text.
#     - *sent_pos* - position of a sentence in the text.
#     - *sent* - text of the sentence.

# %% [markdown]
# ## Data Analysis
#
# Here is the code which provide analysis of sampled data and generate figures for the article (and some more).
#
# The code is interactive, thus one should run it locally for detailed information.

# %%
import numpy as np
import pandas as pd
from math import sqrt
from scipy.stats import pearsonr

import matplotlib as pl
#%matplotlib widget
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.text import Text as plText
from matplotlib.collections import PatchCollection
from matplotlib.patches import Rectangle
import seaborn as sns
import matplotlib.transforms as transforms

from ipywidgets import interact, interactive_output, Select, HBox, FloatSlider
from IPython.display import display

import copy

# Own imports
from intelligibility_figures import *

# %% [markdown]
# Load data to pd.DataFrame for the further analysis.

# %%
# Loading users' data.
user_data = pd.read_csv("data/user_data.csv")#, index_col=0)
users_answers = pd.read_csv("data/user_answers.csv")#, index_col=0)

# %%
text_frame = pd.read_csv("data/texts.csv", index_col=0)
text_frame['id_set']=text_frame['id_set'].astype("str")

# %%
# Add quantitative, instead of qualicative, evaluation of corretness.
users_answers["marks"] = users_answers["correctness"]
users_answers["marks"] = users_answers["marks"].\
                             infer_objects(copy=False).replace({"corr": "1", 
                                                                "pcorr": "0.5", 
                                                                "incorr": "0"}).astype(float)

# %%
# Calculate the average correctness of answers, add it to the corresponding user.
mean_marks = users_answers[["id_user", "marks"]].groupby("id_user").mean()["marks"]
mean_marks.name = "mean_mark"
user_data = user_data.join(mean_marks, on="id_user")

# %%
# Count number of participants by parallel languages and tests.
part_no = pd.DataFrame(columns=["test_id","parallel_lang", "count"])
req = user_data.groupby(["test_id", "parallel_lang"]).count()
part_no["count"] = req["id_user"]
part_no["test_id"] = req.index.get_level_values("test_id")
part_no["parallel_lang"] = req.index.get_level_values("parallel_lang")
part_no.index = range(part_no.shape[0])

# %%
# Count the average correctness for words for fixed test and language.
qu_data = pd.DataFrame()
req = users_answers[["test_id", "parallel_lang", "answer_no", "marks"]].groupby(["test_id", "parallel_lang", "answer_no"]).mean()
qu_data["mean_mark"] = req["marks"]
qu_data["test_id"] = req.index.get_level_values("test_id")
qu_data["parallel_lang"] = req.index.get_level_values("parallel_lang")
qu_data["answer_no"] = req.index.get_level_values("answer_no")
qu_data.index = range(qu_data.shape[0])

# %% [markdown]
# Let us check out the distribution of non-empty answers. We can see that most of innformants try to give as much answer as they can.

# %%
def drawCompletenessStub(test_id):
    drawCompleteness(test_id, users_answers)
    
esel = Select(options=[1, 2, 3, 4, 5, 6], value=1, description='Test: ')
out = interactive_output(drawCompletenessStub, {'test_id': esel})
ui = HBox([out, esel])
display(ui)

# %% [markdown]
# There are the used texts. Words marked by underscore sign was omitted diring tests.

# %%
def show_test(lang, test_no):
    display([t[1].sent for t in text_frame[(text_frame.lang_name==lang) & (text_frame.id_set==test_no)].iterrows()])

lsel = Select(options=['Russian', 'Ukranian', 'Belarussian', 'Bulgarian', 'Serbian', 'Polish', 'Czech', 'Slovak', 'Slovene'], value='Russian', description='Language: ')
esel = Select(options=['1', '2', '3', '4', '5', '6'], value='1', description='Test: ')
ui = HBox([lsel, esel])
out = interactive_output(show_test, {'lang': lsel, 'test_no': esel})
display(ui, out)
# Out:
# ...
# Output()

# %% [markdown]
# ### Analysis of participants
#
#
# The participants of our experiments were students from several Russian universities and schools, and adult volunteers hired on Toloka, a crowd sourcing service of Yandex. Altogether we collected more than 2200 filled forms.

# %%
# Drawing data on the number of partisipants.
display(part_no.sort_values(["parallel_lang", "test_id"]))
# Out:
#     test_id     parallel_lang  count
# 0         1       Belarussian     38
# 9         2       Belarussian     38
# 18        3       Belarussian     37
# 27        4       Belarussian     82
# 36        5       Belarussian     48
# 45        6       Belarussian     37
# 1         1         Bulgarian     37
# 10        2         Bulgarian     37
# 19        3         Bulgarian     37
# 28        4         Bulgarian     37
# 37        5         Bulgarian     48
# 46        6         Bulgarian     37
# 2         1             Czech     37
# 11        2             Czech     38
# 20        3             Czech     37
# 29        4             Czech     45
# 38        5             Czech     37
# 47        6             Czech     37
# 3         1  No Parallel Text     44
# 12        2  No Parallel Text     46
# 21        3  No Parallel Text     37
# 30        4  No Parallel Text     65
# 39        5  No Parallel Text     47
# 48        6  No Parallel Text     44
# ...

# %% [markdown]
# Participants was also allowed entering informatio on their education level and knowledge of foreign Slavic languages. During the test we never provide parallel text in studied foreign laguage.

# %% [markdown]
# Let us consider box plots for every laguage.

# %%
order = ['No Parallel Text', 'Ukranian', 'Belarussian', 'Bulgarian', 'Serbian', 'Slovene', 
         'Polish', 'Slovak', 'Czech']
fig, axes = plt.subplots(1, 1, figsize=(9,6), num=501)
sns.boxplot(x='parallel_lang', 
            y="mean_mark", 
            data=user_data, 
            hue="parallel_lang",
            palette="Dark2", 
            order=order, 
            ax=axes);

# %% [markdown]
# Now we consider results of tests.
#
# A point on the figure deotes the average correctness of an asessor. Axis X denotes language of a parallel text, control group tagged as "Control". Coloured vertical bars denotes 95% confidence intervals of asessors' average answers correctness; cross denotes the average value among answers for this parallel language. Gray horizontal bar denotes the confidence iterval for the control test.
#
# In the table, the row *count* denotes the number of answers, *mean* - average among asessors' answers. *ci_min* and *ci_max* - lower and upper boundaries of 95% confidence interval for average among asessors' answers.

# %%
def showLangsStub(test):
    show_langs(test, user_data, axes)
    fig.show()

# %matplotlib notebook
# %matplotlib widget

fig, axes = plt.subplots(1, 1, figsize=(10.5, 7), num=1)

esel = Select(options=['1', '2', '3', '4', '5', '6', 'All'], value='All', description='Test: ')
out = interactive_output(showLangsStub, {'test': esel})
display(esel, out)
fig.savefig('img_res/Fig_1_general_distribution_users.png', dpi = 600)
# Out:
# Select(description='Test: ', index=6, options=('1', '2', '3', '4', '5', '6', 'All'), value='All')
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# The following figure showing distribution of mean value and confidence interval by languages depending on a test.

# %%
# %matplotlib notebook
# %matplotlib widget

_ = show_langs_by_tests(user_data, axes)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# The next figure subplot (a) demonstrates averaged results grouped by language and tests; a marker shows the average score for a test, its shape corresponds to the test number, colored vertical lines show confidence intervals for tests of this language; the number to the right of vertical lines denotes the difference between maximum and minimum average scores for tests with the same parallel language. Subplots (b) and (c) show p-values and statistical power for separate tests and for a language in general (the last bar in a group) as compared to control group results.1 In our experiments we used a 95% confidence level for both p-values and statistical power marked by the horizontal line at 0.05 in subplots (b) and (c).

# %%
_ = show_tests_by_langs(user_data, axes)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Fig.2 shows that tests 5 and 6 proved to be easier than the other four tests: they yield the highest results in the control group, and their results with any parallel language are higher than average for all languages. The only exception was test 3 with Serbian used as a parallel text language: this was due to a coincidentally higher percentage of cognates among the best restored omitted words and their better recognition by participants.
#
# Results also show that for native speakers of Russian the other two East Slavic languages, Ukrainian and Belarusian, are most helpful in this task. They are closely followed by Bulgarian of the South Slavic group; Serbian and Slovene give lower results. West Slavic languages are the least helpful, with the Czech parallel text leading to worse results than in the control group.

# %% [markdown]
# Now let us consider information on the education level of participants.
#
# Rows have the same description as above; columns are described as following:
# - *sch* - pupols;
# - *bak* - bachelor students;
# - *mag* - master's students;
# - *asp* - PhD students;
# - *fin* - finished their education;
# - *unk* - did not leave information;
# - *unk2* - test 3 participants for the Russian language (we did not gather this information here).
#
# Pink point are belonged to control groups.
#
# Red belongs to the information gathered by all participants, green - the students of 'language' programs (phylology, linguistics, translation, ...), blue - participants who do not have such education.

# %%
user_data[['age', 'mean_mark', 'parallel_lang']]['parallel_lang'] == 'No Parallel Text'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2256    False
# 2257    False
# 2258    False
# 2259    False
# 2260    False
# Name: parallel_lang, Length: 2261, dtype: bool

# %%
def showAgeStub(field, test):
    show_age(field, test, user_data, axes)

# %matplotlib notebook
# %matplotlib widget

fig, axes = plt.subplots(1, 1, figsize=(7,4))#, num=2)

#lsel = Select(options=['Russian', 'Ukranian', 'Serbian', 'All'], value='Russian', description='Language: ')
fsel = Select(options=['age', 'spec'], value='age', description='Values: ')
esel = Select(options=['1', '2', '3', '4', '5', '6', 'All'], value='All', description='Test: ')
ui = HBox([fsel, esel])
out = interactive_output(showAgeStub, {'field': fsel, 'test': esel})
#out.layout.height = '200px'
display(ui, out)
# Out:
# /tmp/ipykernel_7090/913320773.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(1, 1, figsize=(7,4))#, num=2)
# ...
# Output()
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 42.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# It is easy to see that bachelor students have worse results than master students. The 'longer tail' can be explained by the fact that some of students filled the first part of a test only which is more rare for other participants. We can also see that linguistic education makes results of tests better.

# %% [markdown]
# We also investigated dependency of answers and knowledge of other Slavic languages. However, we failed to find any dependency.

# %%
def drawForeignStub(test_no):
    drawForeign(test_no, user_data, axes)

# %matplotlib notebook
# %matplotlib widget

fig, axes = plt.subplots(1, 1, figsize=(7,4), num=201)

esel = Select(options=['1', '2', '3', '4', '5', '6', 'All'], value='1', description='Test: ')
ui = HBox([lsel, esel])
out = interactive_output(drawForeignStub, {'test_no': esel})
axes.set_xticklabels(axes.get_xticklabels(), rotation=15, ha='right')

out.layout.height = '100px'
display(ui, out)
# Out:
# /tmp/ipykernel_432648/1717155626.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=15, ha='right')
# ...
# Output(layout=Layout(height='100px'))
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# It was also considered the hypothesis of the intelligibility of the text depending on the percentage of similar words. It is known that many words of different Slavic languages have common roots. The presence of such words makes it easier to understand the text.
#
# We classified all pairs of omitted words and their equivalents in our experiment into the following four categories.
# 1) Words from parallel texts stemming from the same root as the original omitted word1 (‘same root’ below, as it was described in our method of evaluation of answers in Section 3).
# 2) Words stemming from the same root as synonyms or semantically close words to the omitted one (‘cognate synonyms’).
# 3) Non-cognates, i.e. totally unrelated words having no written or phonetic correspondence with the omitted one (Frunza, 2006) (‘non-cognates’).
# 4) False friends to the omitted Russian word, the parallel text words that “appear similar”, but have “different meanings in all contexts” (Frunza (2006), p.2) (‘false friends’). E.g. "за его спиной" (Rus) - "у яго за \_плячыма\_" (Bel) _By his back_, but Belorussian 'плячыма' could be considered as Russian 'плечами' _sholders_.
#
# Below is the markup of the words of the texts by similarity. The sign 1 indicates words that have a same root. The sign 2 indicates cognate synonyms. The 0 sign indicates words that have no analogues or any similarity in their native language (non-cognates). The sign ! denotes 'false friends'.

# %% [markdown]
# ```Python
# sim_rus1={#    0        10        20        30        40
# "Belorussian":"101!121122201111112110111121021111011011100",
# "Bulgarian"  :"200!!100201020111122201122012201!12112211!0",
# "Czech"      :"010!00020021010011222!01000202!2!2221!21000",
# "Polish"     :"021!01102022102111202201010002!000!01001002",
# "Serbian"    :"01000100!011210111220!11220100!1!122122100!",
# "Slovak"     :"220!00000022010101220!110002220210211020002",
# "Ukranian"   :"1211121020121111012110111221010111001210100",
# "Slovene"    :"002!012!!020000011021!01222002!2!020102112!",
# }
#
# sim_rus2={#    0        10        20        30        40
# "Belorussian":"110211112110001110210202!0!!111121201020",
# "Bulgarian"  :"!10111200021!121100100010!1211120121!120",
# "Czech"      :"!!02010201002!21000100200!2001102121!0!0",
# "Polish"     :"10000001!120!02100010022!0101112!021!020",
# "Serbian"    :"!0011010!020012110!100020!10111!11210120",
# "Slovak"     :"!00201022100022100010000!!2011120121!120",
# "Ukranian"   :"21011110!110201110010102!0221111!1201220",
# "Slovene"    :"!201100000!0202102!1000222!2111!!021!1!0",
# }
#
# sim_rus3={#    0        10        20        30
# "Belorussian":"100220101222!122111!1!121!10!211121",
# "Bulgarian"  :"12100111!0002100112!1!101!11!111101",
# "Czech"      :"110220!002000!00!1!22!0!!!!2!1!102!",
# "Polish"     :"100222!01202!!00!12!2!12!!!2!1!1121",
# "Ukranian"   :"111022!012!2!!00!1211!12!!!2!1!1121",
# "Slovak"     :"111220!0220!0!!0!1!!2!22!2!2!!2111!",
# "Slovene"    :"102222!200020!!0!1122!12!1!2!!2110!",
# "Serbian"    :"11!0211!012001101100201!1!10!101122",
# }
#
# sim_rus4={#    0        10        20        30        40
# "Ukranian"   :"110!1!1!21212!22!1!2!01!10001!21000!1001!00!",
# "Belorussian":"01!1212020212222!2!2!0121!001!2!!00210011000",
# "Polish"     :"20!12!202!022022!2!2!01010!01!20!00221121000",
# "Bulgarian"  :"02012212!1!2!121!!22111!211111010!020121110!",
# "Czech"      :"02!11!!20!200021!122201010!!0!01202022111220",
# "Slovak"     :"!2201!220!210021!2!02!1010!000012010121!1!!2",
# "Slovene"    :"22000!0002220021!2122202!2202220!0!210121110",
# "Serbian"    :"!20112000122221200222102!2121!02!00!0101100!",
# }
#
# sim_rus5={#    0        10        20        30        40
# "Ukranian"   :"211101111021110111211110!10020102!010",
# "Belorussian":"011001010001100!1102111!!000201022!10",
# "Polish"     :"21100101100200201102111000!!101010010",
# "Bulgarian"  :"222!00!!10221!2!12!01111!2111221121!1",
# "Czech"      :"221!!0!110221!201002111!!000101111010",
# "Slovak"     :"22!!1!!112221!!111021110!000111010210",
# "Slovene"    :"2!20!20!!!2200!1!102111!02111!!010212",
# "Serbian"    :"2!2!!!!!00221!!011!!1110001112!000002",
# }
#
# sim_rus6={#    0        10        20        30        40
# "Ukranian"   :"!1110211210012210001001111210111101",
# "Belorussian":"!11112110101111!0011010111120111101",
# "Polish"     :"!11122110100122!0022001121100122200",
# "Bulgarian"  :"111110011101111112!10!0111000121112",
# "Czech"      :"!11101200000100!00010!0!0!1!100001!",
# "Serbian"    :"11111201211!1!!1!!!10!01!102!211112",
# "Slovene"    :"!12120211100122!2202002221!22!22120",
# }
# ```

# %% [markdown]
# The code below allows you to see the correspondence of the missing words with each other. Note that in some languages the words in some sentences of the first text are reversed. This flaw has been fixed in the table below.

# %%
def showWordsStub(test_no: str):
    showWords(test_no, text_frame)

# %matplotlib notebook

esel = Select(options=['1', '2', '3', '4', '5', '6'], value='1', description='Test: ')
ui = HBox([esel])
out = interactive_output(showWordsStub, {'test_no': esel})
display(ui, out)
# Out:
# ...
# Output()

# %% [markdown]
# Now let's build a figure showing the dependence of the intelligibility of a word on its type:  same root, cognate synonym, non-cognate, and false friend. The figure shows the difference between the intelligibility of an individual word in a control group and in a test with a parallel language (as grouped by test and language respectively). In both subplots a) and b) one point means average intelligibility of an individual word (i.e. how well a Russian word was restored in a control group test or in a test with a parallel text in a given foreign language averaged by occurrences in this test and by all participants for this language). Colored crosses represent the average, and lines show 95% confidence interval for tests with parallel language texts (results are grouped by tests). Red circles and lines correspond to the same figures for control group tests in subplot b). The confidence intervals are drawn in the same color as the dots, the colors correspond to the types of words and tests. The red confidence intervals in the figure on the left show the corresponding confidence intervals of the control (graph on the right) and allow you to visually assess changes in comprehension in the presence of parallel text.

# %%
from matplotlib.patches import Rectangle
import warnings
import copy

# %%
# %matplotlib notebook
# %matplotlib widget
warnings.filterwarnings('ignore')
# fig, axes = plt.subplots(1, 2, sharey=True, figsize=(10,4), num=3)
# plt.subplots_adjust(hspace=0.5, wspace=0.3, top=0.9, bottom=0.1, left=0.1, right=0.9)
fig, axes = plt.subplots(2, 1, sharey=True, figsize=(9,6))#, num=3)
fig.tight_layout(h_pad=3.0)

showIntelligibility(qu_data, text_frame, axes, fig)

warnings.filterwarnings('default')
# Out:
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 15.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 34.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/edward/.local/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 22.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# And now separately for every language.

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')

fig, axes = plt.subplots(8, 1, sharey=True, figsize=(10,40))#, num=3)
fig.tight_layout(h_pad=4.5)

all_resn, all_tests = processIntelligibility(qu_data, text_frame)
for n, lang in enumerate(['Belarussian', 'Bulgarian', 'Czech', 'Polish', 'Serbian', 'Slovak', 'Slovene', 'Ukranian']):
    # showIntelligibility(qu_data, text_frame, axes[n], fig, lang)
    drawIntelligibility4a(all_resn, all_tests, axes[n], lang)
    axes[n].set_title(lang)
plt.show()
warnings.filterwarnings('default')

# %% [markdown]
# The figures show that in Russian, same root pairs are guessed about one and a half times better than in the absence of a hint. For words cognate synonyms, the situation is not so clear. There is a significant improvement in the first test while little improvement in the second and third texts. Non-cognates and false friends rather make it difficult to understand the text.

# %% [markdown]
# Now let's see how the tests behave depending on the percentage of similar words in the parallel text.
#
# The ratio of the percentage of similar words and test results is shown below. Tests with different parallel texts are shown in different colors, but the test numbers are not indicated. The relevant information can be found in a table. The gray diagonal line is given as the base and corresponds to the line ((0,0), (1,1)).

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
showIntel('Same', user_data, qu_data, text_frame, axes[0][0], fig)
showIntel('Similar', user_data, qu_data, text_frame, axes[0][1], fig)
showIntel('No analogues', user_data, qu_data, text_frame, axes[1][0], fig, 2)
showIntel('False Friends', user_data, qu_data, text_frame, axes[1][1], fig, 1)
fig.savefig('img_res/Fig_5_all_correlation_on_type.png', dpi = 600)
# Out:
#                   %Same Words, Test1  Avg.Results, Test1  %Same .Words, Test2  \
# lang
# Belarussian                    0.450            0.777303             0.674419
# Bulgarian                      0.425            0.719932             0.348837
# Czech                          0.200            0.595625             0.162791
# Polish                         0.275            0.674716             0.232558
# Serbian                        0.375            0.585897             0.348837
# Slovak                         0.250            0.656356             0.186047
# Slovene                        0.225            0.658108             0.186047
# Ukranian                       0.450            0.764189             0.558140
# No Parallel Text                 NaN            0.563953                  NaN
#
#                   Avg.Results, Test2  %Same .Words, Test3  Avg.Results, Test3  \
# lang
# Belarussian                 0.766524             0.457143            0.735907
# ...

# %% [markdown]
# And now draw the overall information about languages.

# %%
# %matplotlib widget

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
showIntel2('Same', user_data, qu_data, text_frame, axes[0][0], fig)
showIntel2('Similar', user_data, qu_data, text_frame, axes[0][1], fig)
showIntel2('No analogues', user_data, qu_data, text_frame, axes[1][0], fig, 2)
showIntel2('False Friends', user_data, qu_data, text_frame, axes[1][1], fig, 1)
# fig.savefig('img_res/Fig_5_all_correlation_on_type.png', dpi = 600)
# Out:
# /home/edward/.local/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Save it in a table.

# %%
test_lens = [0, 43, 40, 35, 44, 37, 37]

means = np.zeros(7)
intellig = pd.DataFrame()
for test_no in range(1, 7):
    for sameness in ['1', '0', '2', '!']:
        intellig['cnt'+sameness+str(test_no)] = \
                    all_resn[test_no-1][(all_resn[test_no-1]["type"]==sameness)] \
                    [['lang', 'w_par']].groupby('lang').count()['w_par']
        intellig['cnt'+sameness+str(test_no)] = intellig['cnt'+sameness+str(test_no)] / test_lens[test_no]
        means[test_no] = user_data[['parallel_lang', 'mean_mark']] \
                         [(user_data.test_id == test_no) & \
                         (user_data.parallel_lang == 'No Parallel Text')]['mean_mark'].mean()
    intellig['intel'+str(test_no)] = all_resn[test_no-1][['lang', 'w_par']].groupby('lang').mean()
intellig = intellig.fillna(0)

# %%
intellig
# Out:
#                 cnt11     cnt01     cnt21     cnt!1    intel1  cnt12  cnt02  \
# lang
# Belarussian  0.674419  0.139535  0.162791  0.023256  0.766524  0.450  0.325
# Bulgarian    0.348837  0.302326  0.232558  0.116279  0.654305  0.425  0.300
# Czech        0.162791  0.441860  0.302326  0.093023  0.520427  0.200  0.500
# Polish       0.232558  0.488372  0.162791  0.116279  0.565245  0.275  0.450
# Serbian      0.348837  0.395349  0.162791  0.093023  0.626744  0.375  0.400
# Slovak       0.186047  0.441860  0.302326  0.069767  0.602123  0.250  0.425
# Slovene      0.186047  0.395349  0.255814  0.162791  0.622250  0.225  0.400
# Ukranian     0.558140  0.279070  0.162791  0.000000  0.786720  0.450  0.275
#
#              cnt22  cnt!2    intel2  ...     cnt15     cnt05     cnt25  \
# lang                                 ...
# Belarussian  0.200  0.025  0.777303  ...  0.351351  0.432432  0.135135
# Bulgarian    0.150  0.125  0.719932  ...  0.405405  0.135135  0.270270
# ...

# %%
warnings.filterwarnings('ignore')

index = []
for lang in order:
    for test_no in range(1, 7):
        index.append((lang, test_no))

intellig2 = pd.DataFrame(index=index, columns=['lang', 'test', 'same', 'close', 'nothing', 'false', 'intellig', 'control'])
for lang in order:
    if lang == 'No Parallel Text':
        continue
    for test_no in range(1, 7):
        for sameness, s_name in zip(['1', '2', '0', '!'], ['same', 'close', 'nothing', 'false']):
            intellig2[s_name][(lang, test_no)] = intellig.loc[lang, 'cnt'+sameness+str(test_no)]
            intellig2['lang'][(lang, test_no)] = lang
            intellig2['test'][(lang, test_no)] = test_no
        intellig2['intellig'][(lang, test_no)] = intellig['intel'+str(test_no)][lang]
        intellig2['control'][(lang, test_no)] = means[test_no]

warnings.filterwarnings('default')

# %%
intellig2#.sort_values('nothing')
# Out:
#                               lang test      same     close   nothing  \
# (No Parallel Text, 1)          NaN  NaN       NaN       NaN       NaN
# (No Parallel Text, 2)          NaN  NaN       NaN       NaN       NaN
# (No Parallel Text, 3)          NaN  NaN       NaN       NaN       NaN
# (No Parallel Text, 4)          NaN  NaN       NaN       NaN       NaN
# (No Parallel Text, 5)          NaN  NaN       NaN       NaN       NaN
# (No Parallel Text, 6)          NaN  NaN       NaN       NaN       NaN
# (Ukranian, 1)             Ukranian    1   0.55814  0.162791   0.27907
# (Ukranian, 2)             Ukranian    2      0.45     0.175     0.275
# (Ukranian, 3)             Ukranian    3  0.371429  0.257143  0.085714
# (Ukranian, 4)             Ukranian    4  0.386364  0.136364  0.318182
# (Ukranian, 5)             Ukranian    5  0.513514  0.162162   0.27027
# (Ukranian, 6)             Ukranian    6  0.513514  0.108108  0.297297
# ...

# %%
intellig2.to_excel("data_out/tests_intelligibility.xlsx", index=False)

# %% [markdown]
# Here is more convinient interactive interface to analyse the same information.

# %%
def showIntelStub(sameness):
    showIntel(sameness, user_data, qu_data, text_frame, axes, fig)

# %matplotlib notebook
# %matplotlib widget

fig, axes = plt.subplots(1, 1, figsize=(5, 5))#, num=4)

hsel = Select(options=['Same', 'Similar', 'Same and Similar', 'No analogues', 'False Friends'], value='Same')
out = interactive_output(showIntelStub, {'sameness':hsel})
display(hsel, out)
# Out:
# /home/edward/.local/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Select(options=('Same', 'Similar', 'Same and Similar', 'No analogues', 'False Friends'), value='Same')
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# And here is a 3D representation of the same data (just in case, for bright insights).

# %%
import plotly.express as px
import numpy as np

# %%
all_resn, all_tests = processIntelligibility(qu_data, text_frame)

# %%
test_len = [43, 40, 35, 44, 37, 37]

s_c = []
n_c = []
m_c = []
intl = []
tests_no = []
names = []

for test_no in range(6):
    s_c_c = all_resn[test_no][(all_resn[test_no]["type"]=='1')][['lang', 'w_par']].groupby('lang').count()['w_par']
    n_c_c = all_resn[test_no][(all_resn[test_no]["type"]=='2')][['lang', 'w_par']].groupby('lang').count()['w_par']
    m_c_c = all_resn[test_no][(all_resn[test_no]["type"]=='0')][['lang', 'w_par']].groupby('lang').count()['w_par']
    s_c_c = s_c_c / test_len[test_no]
    n_c_c = n_c_c / test_len[test_no]
    m_c_c = m_c_c / test_len[test_no]
#     elif sameness == 'False Friends':
#         intellig['cnt'+str(test_no)] = all_resn[test_no-1][(all_resn[test_no-1]["type"]=='!')][['lang', 'w_par']].groupby('lang').count()['w_par']
#     else:
#         intellig['cnt'+str(test_no)] = all_resn[test_no-1][(all_resn[test_no-1]["type"]=='2')][['lang', 'w_par']].groupby('lang').count()['w_par']
    intl_c = all_resn[test_no][['lang', 'w_par']].groupby('lang').mean()
    s_c.extend(s_c_c)
    n_c.extend(n_c_c)
    m_c.extend(m_c_c)
    intl.extend(intl_c['w_par'])
    names.extend(intl_c.index)
    tests_no.extend([test_no for i in s_c_c])
    
#     mean = user_data[['parallel_lang', 'mean_mark']] \
#                      [(user_data.test_id == test_no) & \
#                       (user_data.parallel_lang == 'No Parallel Text')].mean().iloc[0]

    
#     if axes != None:
#         sns.scatterplot(x='cnt'+str(test_no), y='intel'+str(test_no), data=intellig, marker=markers[test_no],
intellig = pd.DataFrame([np.array(s_c), np.array(n_c), np.array(m_c), np.array(intl), names, np.array(tests_no)]).T
intellig.columns = ['sam', 'sim', 'dif', 'intl', 'lang', 'test']

# %%
fig = px.scatter_3d(intellig, x="sam", y="dif", z="intl", color="lang", symbol="test")
fig.show()

# %%
fig = px.scatter_ternary(intellig, a="sam", b="sim", c="dif", text=intellig["intl"].astype(str).map(lambda x: x[:4]), size_max=1)
fig.show()

# %% [markdown]
# Now let us try to approximate the behaviour of different types of word equivalents.

# %%
from sklearn.linear_model import LinearRegression

# %%
all_resn, all_tests = processIntelligibility(qu_data, text_frame)

# %%
all_resn2 = pd.concat(all_resn)
#all_resn2['type'] = all_resn2['type'].replace({'1':'Same root', '2':'Synonym', '0':'Non-cognate', '!':'False friends'})

# %% [markdown]
# We approximated the trends for all points of the same class using the least square algorithm (these are drawn as coloured lines in figure below).

# %%
for mark, kind in {'1':'Same root', '2':'Synonym', '0':'Non-cognate', '!':'False friends'}.items():
    d1 = all_resn2[all_resn2['type']==mark]
    reg = LinearRegression().fit([[d] for d in d1['wo_par']], [d for d in d1['w_par']])
    print(f'{kind:15}, coef = {reg.coef_[0]:5.3}, intercept = {reg.intercept_:5.3}')
# Out:
# Same root      , coef = 0.346, intercept = 0.606
# Synonym        , coef = 0.598, intercept = 0.337
# Non-cognate    , coef = 0.764, intercept = 0.108
# False friends  , coef = 0.688, intercept = 0.194

# %% [markdown]
# In this figure we compare how the intelligibility of an omitted Russian word changes depending on the class of its equivalent in a parallel text. A point at figure corresponds to the relation between the intelligibility of a word in a control group test and in a test with a given parallel language. The colour and the marker of a point correspond to the class of the word’s equivalent in a parallel text.

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 5), num=41)

palt = [sns.palettes.color_palette("tab10")[2],
       sns.palettes.color_palette("tab10")[0],
       sns.palettes.color_palette("tab10")[3],
       sns.palettes.color_palette("tab10")[1]
      ]
#for typ, marker in zip(['1', '2', '0', '!'], ['.', '+', 'x', '*']):
sns.scatterplot(data=all_resn2, x='wo_par', y='w_par', 
                style='type', hue='type', size=1, ax=axes, palette=palt, alpha=0.5)

for t, s, c in zip(['1', '2', '0', '!'], ["solid", "dotted", "dashed", "dashdot"], palt):
    d1 = all_resn2[all_resn2['type']==t]
    reg = LinearRegression().fit(np.array([[d] for d in d1['wo_par']]), np.array([d for d in d1['w_par']]))
    plt.plot(np.array([0, 1]), np.array([reg.intercept_, reg.intercept_+reg.coef_]), linestyle=s
             , color=c)
axes.set_xlim(0, 1)    
axes.set_ylim(0, 1)
# axes.set_title("Word's intelligibility on a class of cognate")
axes.set_xlabel("Word's intelligibility in control text")
axes.set_ylabel("Word's intelligibility with a parallel text")
# plt.legend(['Same root', 'Synonym', 'Non-cognate', 'False friends'])

# for typ, m in zip(['Same root', 'Synonym', 'Non-cognate', 'False friends'], ['o', 'x', '+', 's']):
_ = axes.legend(handles=[Line2D([], [], marker=m, color=c, linestyle=s) 
                         for m,s,c in zip(['o', 'x', '+', 's'], 
                                          ["solid", "dotted", "dashed", "dashdot"], palt
#                                           sns.palettes.color_palette("tab10")[:4]
                                         )
                        ], 
                labels=['Same root', 'Close Words', 'Non-cognate', 'False friends'],
                loc = 'lower right', ncol=2, title='')

divx, divy = 10, 10
figx, figy = 1, 1

for i in range(divx):
    sns.lineplot(x=[0, figx], y=[i*figx/divx, i*figy/divy], color = '#888888', ax = axes, 
                 size=1, legend=None, style=True, dashes=[(4,4)])
    sns.lineplot(x=[i*figx/divx, i*figy/divy], y=[0, figy], color = '#888888', ax = axes, 
                 size=1, legend=None, style=True, linestyle='--')

fig.savefig('img_res/Fig_6_control_test_vs_cognate_classes.png', dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Here is another representation of the same data. We divided the figure on square tiles and draw in every tile histogram for our four types of equivalent words. Instead of drawing bars, we denote the density of points in the selected square by opacity of the corresponding color.

# %%
divx, divy = 10, 10
freqs = np.zeros((4, divx+1, divy+1))
corr = {'1':0, '2':1, '0':2, '!':3}

for i, row in all_resn2.iterrows():
#     print(corr[row['type']], nt(row['wo_par']*10), int(row['w_par']*10))
    freqs[corr[row['type']]][int(row['wo_par']*divx)][int(row['w_par']*divy)] += 1
    
for i in range(4):
    freqs[i] /= freqs[i].max()

palt = [sns.palettes.color_palette("tab10")[2],
       sns.palettes.color_palette("tab10")[0],
       sns.palettes.color_palette("tab10")[3],
       sns.palettes.color_palette("tab10")[1]
      ]

figx, figy = 5, 5
fig, axis = plt.subplots(1, 1, figsize=(figx, figy), num=45)

for i in range(divx):
    for j in range(divy):
        for k in range(4):
#             k=0
            patches = [Rectangle((figx/(divx*4)*(i*4+k), figy/divy*j), figx/(divx*4), figy/divy, edgecolor=palt[k])]
            pc = PatchCollection(patches, alpha = freqs[k][i][j], facecolor=palt[k])
            axis.add_collection(pc)  

for k in range(4):
    patches = [Rectangle((figx/(divx*4)*(4*divx-4+k), figy/divy*0), figx/(divx*4), figy/(divy*4), edgecolor=palt[k])]
    pc = PatchCollection(patches, facecolor=palt[k])
    axis.add_collection(pc)  
# axis.text(figx/(divx*4)*(4*9+k), figy/divy*3.1, "120!"[k])
for i in range(divx):
    sns.lineplot(x=[0, figx], y=[i*figx/divx, i*figy/divy], color = '#888888', ax = axis, 
                 size=1, legend=None, style=True, dashes=[(4,4)])
    sns.lineplot(x=[i*figx/divx, i*figy/divy], y=[0, figy], color = '#888888', ax = axis, 
                 size=1, legend=None, style=True, linestyle='--')
    
sns.lineplot(x=[0, figx], y=[0, figy], color = '#888888', ax = axis, 
             size=1, legend=None)

axis.set_xlim(0, figx);
axis.set_ylim(0, figy);
axis.set_xlabel("Word's intelligibility in control text")
axis.set_ylabel("Word's intelligibility with a parallel text")
labs = [f"{i/divx:4.2}" if i%2==0 else "" for i in range(divx+1)]
labs[0], labs[-1] = "0", "1"
axis.set_xticks([figx/divx*i for i in range(divx+1)])
axis.set_xticklabels(labs)#, rotation=30);
axis.set_yticks([figx/divy*i for i in range(divy+1)])
axis.set_yticklabels(labs);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Now let us draw the same information grouping points by a language and a test.

# %%
all_resn4 = all_resn.copy()
for i in range(len(all_resn4)):
    all_resn4[i]['test_no'] = i + 1
    
all_resn4 = pd.concat(all_resn4)

# %%
fig, axes2 = plt.subplots(6, 8, figsize=(20, 20), num=61)

palt = [sns.palettes.color_palette("tab10")[2],
       sns.palettes.color_palette("tab10")[0],
       sns.palettes.color_palette("tab10")[3],
       sns.palettes.color_palette("tab10")[1]
      ]
#for typ, marker in zip(['1', '2', '0', '!'], ['.', '+', 'x', '*']):

order = ['Ukranian', 'Belarussian', 'Bulgarian', 'Serbian', 'Slovene', 
         'Polish', 'Slovak', 'Czech']

for test_no in range(1, 7):
    for lang_no, lang in enumerate(order):
        if lang == 'Slovak' and test_no == 6:
            continue
        
        axes = axes2[test_no - 1][lang_no]
        if test_no == 1:
            axes.set_title(lang)
        
        palt2 = []
        for c, t in zip(palt, ['1', '2', '0', '!']):
            if all_resn4[(all_resn4['type']==t) & 
                         (all_resn4['test_no']==test_no) & 
                         (all_resn4['lang']==lang)].shape[0] != 0:
                palt2.append(c)
        
        for t, s, c in zip(['1', '2', '0', '!'], ["solid", "dotted", "dashed", "dashdot"], palt):
            d1 = all_resn4[(all_resn4['type']==t) & (all_resn4['test_no']==test_no) & (all_resn4['lang']==lang)]
            sns.scatterplot(data=d1, 
                            x='wo_par', y='w_par', style='type', #hue='type', 
                            size=1, ax=axes, color=c, alpha=0.5)
            if d1.shape[0] < 3:
                continue
            reg = LinearRegression().fit(np.array(object=[[d] for d in d1['wo_par']]), 
                                         np.array([d for d in d1['w_par']]))
            axes.plot(np.array([0, 1]), [reg.intercept_, reg.intercept_+reg.coef_[0]], 
                     linestyle=s, color=c)
        axes.set_xlim(0, 1)    
        axes.set_ylim(0, 1)
        axes.set_xlabel = ''
        axes.set_ylabel = ''
        axes.get_legend().remove()
        
        divx, divy = 10, 10
        figx, figy = 1, 1

        for i in range(divx):
            sns.lineplot(x=[0, figx], y=[i*figx/divx, i*figy/divy], color = '#888888', ax = axes, 
                         size=1, legend=None, style=True, dashes=[(4,4)])
            sns.lineplot(x=[i*figx/divx, i*figy/divy], y=[0, figy], color = '#888888', ax = axes, 
                         size=1, legend=None, style=True, linestyle='--')

plt.show()
fig.savefig('img_res/Fig_6_control_test_vs_cognate_classes_all48.png', dpi = 200)
# Out:
# <img src="data:image/png;base64,..." width="964">

# %% [markdown]
# And the same again but gouping by a language only.

# %%
fig, axes2 = plt.subplots(2, 4, figsize=(20, 10), num=61)

palt = [sns.palettes.color_palette("tab10")[2],
        sns.palettes.color_palette("tab10")[0],
        sns.palettes.color_palette("tab10")[3],
        sns.palettes.color_palette("tab10")[1]
       ]
order = ['Czech', 'Slovak', 'Polish', 'Belarussian', 
         'Slovene', 'Serbian', 'Bulgarian', 'Ukranian']

for lang_no, lang in enumerate(order):
    axes = axes2[int(lang_no/4)][lang_no%4]
    axes.set_title(lang)

    palt2 = []
    for c, t in zip(palt, ['1', '2', '0', '!']):
        if all_resn4[(all_resn4['type']==t) & 
                     (all_resn4['lang']==lang)].shape[0] != 0:
            palt2.append(c)

#         sns.scatterplot(data=all_resn4[(all_resn4['test_no']==test_no) & (all_resn4['lang']==lang)], 
#                         x='wo_par', y='w_par', style='type', hue='type', 
#                         size=1, ax=axes, palette=palt2, alpha=0.5)

    for t, s, c in zip(['1', '2', '0', '!'], ["solid", "dotted", "dashed", "dashdot"], palt):
        d1 = all_resn4[(all_resn4['type']==t) & (all_resn4['lang']==lang)]
        sns.scatterplot(data=d1, 
                        x='wo_par', y='w_par', style='type', #hue='type', 
                        size=1, ax=axes, color=c, alpha=0.5)
        if d1.shape[0] < 3:
            continue
        reg = LinearRegression().fit(np.array(object=[[d] for d in d1['wo_par']]), 
                                     np.array([d for d in d1['w_par']]))
        axes.plot(np.array([0, 1]), [reg.intercept_, reg.intercept_+reg.coef_[0]], 
                 linestyle=s, color=c)
    axes.set_xlim(0, 1)    
    axes.set_ylim(0, 1)
    axes.set_xlabel("Word's intelligibility in control text")
    axes.set_ylabel('')
    axes.get_legend().remove()

    divx, divy = 10, 10
    figx, figy = 1, 1

    for i in range(divx):
        sns.lineplot(x=[0, figx], y=[i*figx/divx, i*figy/divy], color = '#888888', ax = axes, 
                     size=1, legend=None, style=True, dashes=[(4,4)])
        sns.lineplot(x=[i*figx/divx, i*figy/divy], y=[0, figy], color = '#888888', ax = axes, 
                     size=1, legend=None, style=True, linestyle='--')


    # axes.set_title("Word's intelligibility on a class of cognate")
axes2[0][0].set_ylabel("Word's intelligibility with a parallel text")
axes2[1][0].set_ylabel("Word's intelligibility with a parallel text")
        
plt.show()
fig.savefig('img_res/Fig_6_control_test_vs_cognate_classes_all8_lang.png', dpi = 200)
# Out:
# <img src="data:image/png;base64,..." width="2000.25">

# %% [markdown]
# Below you can see the change in the results for individual words in the presence or absence of parallel text. Here you can select the test number, the threshold value, whether the value should be less than or greater than the threshold value, and which type of words should be displayed.
#
# Filtering is performed based on the values shown on the parallel texts.

# %%
def showWords2Stub(test_n, coef, word_type, thr):
    showWords2(test_n, coef, word_type, thr, qu_data, text_frame)

tsel = Select(options=['1', '2', '3', '4', '5', '6'], value='1', description='Test: ')
lsel = Select(options=['<', '>'], value='<', description="value")
trsel = FloatSlider(min=0, max=1, step=0.1, value=0.5, description="threshold")
ssel = Select(options=['Same', 'Similar', 'No analagues', 'False friend', 'All'], 
              value='Same', description="Words are")
ui = HBox([tsel, lsel, trsel, ssel])
out = interactive_output(showWords2Stub, {'test_n': tsel, 'coef':lsel, 'word_type': ssel, 'thr': trsel})
#out.layout.height = '320px'
display(ui, out)
# Out:
# ...
# Output()

# %% [markdown]
# Now let us see the words contexts.

# %%
text_frame
# Out:
#     id_set lang_name  sent_pos  \
# 0        1   Russian         0
# 1        1   Russian         1
# 2        1   Russian         2
# 3        1   Russian         3
# 4        1   Russian         4
# ..     ...       ...       ...
# 922      6   Slovene        11
# 923      6   Slovene        12
# 924      6   Slovene        13
# 925      6   Slovene        14
# 926      6   Slovene        15
#
#                                                   sent
# 0    Пилат _повернулся_ и пошел по мосту назад к _с...
# 1    Он знал, что теперь у него за _спиною_ на помо...
# 2    Как легионеры снимают с него _веревки_, неволь...
# 3    Он _знал_, что в это же время конвой ведет к б...
# 4    Лишь оказавшись за помостом, в тылу его, Пилат...
# ..                                                 ...
# 922                »O ne! To more nekdo _potrditi_!«\n
# 923  je nadvse prepričano odvrnil profesor, govoreč...
# 924  _Nagnila_ sta se tedaj k njemu z obeh strani, ...
# ...

# %%
test_no = '6'

# %%
if test_no == '6':
    langs = ['Russian', 'Ukranian', 'Belarussian', 'Bulgarian', 'Polish', 'Czech', 'Serbian', 'Slovene'] # Test 6
else:
    langs = ['Russian', 'Ukranian', 'Belarussian', 'Bulgarian', 'Polish', 'Czech', 'Slovak', 'Serbian', 'Slovene']
    
#makeWords(langs, text_frame, test_no)
words=pd.DataFrame()
for lang in langs:
    words0=[]
    for i, sent in enumerate(text_frame['sent'][(text_frame['id_set']==test_no) & (text_frame['lang_name']==lang)]):
        [words0.append((s, i, sent)) for j, s in enumerate(sent.split('_')) if j%2==1]
    words[lang]=words0
words
# Out:
#                                               Russian  \
# 0   (лицу, 0, Поэт провел рукою по _лицу_, как чел...
# 1   (вечер, 0, Поэт провел рукою по _лицу_, как че...
# 2   (почернела, 1, Вода в пруде _почернела_, и лег...
# 3   (весла, 1, Вода в пруде _почернела_, и легкая ...
# 4   (гражданки, 1, Вода в пруде _почернела_, и лег...
# 5   (скамейках, 2, В аллеях на _скамейках_ появила...
# 6   (публика, 2, В аллеях на _скамейках_ появилась...
# 7   (квадрата, 2, В аллеях на _скамейках_ появилас...
# 8   (луна, 3, Небо над Москвой как бы выцвело, и с...
# 9   (золотая, 3, Небо над Москвой как бы выцвело, ...
# 10  (заметил, 4, «Как же это я не _заметил_, что о...
# 11  (рассказ, 4, «Как же это я не _заметил_, что о...
# 12  (вечер, 4, «Как же это я не _заметил_, что он ...
# 13  (рассказывал, 5, А может, это и не он _рассказ...
# 14  (рассказывал, 6, Но надо полагать, что все-так...
# 15  (лицо, 6, Но надо полагать, что все-таки _расс...
# ...

# %%
ans_counts = users_answers[users_answers['test_id']==int(test_no)]. \
             groupby(['answer_no', 'parallel_lang', 'correctness']).count()

# %%
ans_counts
# Out:
#                                      Unnamed: 0  id_user  test_id  answer  \
# answer_no parallel_lang correctness
# 0         Belarussian   corr                 19       19       19      19
#                         incorr                7        7        7       7
#                         pcorr                11       11       11      11
#           Bulgarian     corr                 36       36       36      36
#                         incorr                1        1        1       1
# ...                                         ...      ...      ...     ...
# 34        Slovene       corr                 17       17       17      17
#                         incorr               14       14       14       2
#                         pcorr                 5        5        5       5
#           Ukranian      corr                 36       36       36      36
#                         incorr                1        1        1       0
#
#                                      marks
# ...

# %%
new_columns = ['answer_no', 'cognate_class', 'orig_word', 
               'control_count', 'control_correct', 'control_correct_percent', 
               'control_pcorrect', 'control_pcorrect_percent', 'control_incorrect', 'control_incorrect_percent',  
               'parallel_lang', 'parallel_word', 'parallel_count',
               'parallel_correct', 'parallel_correct_percent', 
               'parallel_pcorrect', 'parallel_pcorrect_percent', 'parallel_incorrect', 'parallel_incorrect_percent',  
               'rus_sent', 'parallel_sent'
              ]

# %%
data = []
corr_types = {'!':'False friend', '1':'Same root', '2':'Close words', '0':'Nothing similar'}

for ans_no in range(max([ind[0] for ind in ans_counts.index])):
    for lang in langs[1:]:
        cont_all = 0
        for corr in ['corr', 'pcorr', 'incorr']:
            try:
                cont_all += ans_counts['id_user'][(ans_no, 'No Parallel Text', corr)]
            except Exception:
                pass
        corr_type = corr_types[all_resn[int(test_no)-1][all_resn[int(test_no)-1]['lang']==lang]['type'].iloc[ans_no]]
        r = [ans_no, corr_type, words['Russian'][ans_no][0], cont_all]
        for corr in ['corr', 'pcorr', 'incorr']:
            try:
                r.extend((ans_counts['id_user'][(ans_no, 'No Parallel Text', corr)], 
                          ans_counts['id_user'][(ans_no, 'No Parallel Text', corr)]/cont_all))
            except Exception:
                r.extend((0, 0))
                
        cont_all = 0
        for corr in ['corr', 'pcorr', 'incorr']:
            try:
                cont_all += ans_counts['id_user'][(ans_no, lang, corr)]
            except Exception:
                pass
        r.extend((lang, words[lang][ans_no][0], cont_all))
        for corr in ['corr', 'pcorr', 'incorr']:
            try:
                r.extend((ans_counts['id_user'][(ans_no, lang, corr)], ans_counts['id_user'][(ans_no, lang, corr)]/cont_all))
            except Exception:
                r.extend((0, 0))
                
        r.extend((words['Russian'][ans_no][2], words[lang][ans_no][2]))
        
        data.append(r)
        
#         print(r)
ans_stat = pd.DataFrame(data=data, columns=new_columns)
ans_stat
# Out:
#      answer_no    cognate_class orig_word  control_count  control_correct  \
# 0            0     False friend      лицу             44               27
# 1            0     False friend      лицу             44               27
# 2            0        Same root      лицу             44               27
# 3            0     False friend      лицу             44               27
# 4            0     False friend      лицу             44               27
# ..         ...              ...       ...            ...              ...
# 233         33        Same root     тайно             44               22
# 234         33  Nothing similar     тайно             44               22
# 235         33        Same root     тайно             44               22
# 236         33        Same root     тайно             44               22
# 237         33      Close words     тайно             44               22
#
#      control_correct_percent  control_pcorrect  control_pcorrect_percent  \
# ...

# %%
ans_stat.to_excel(f'data_out/contexts_{test_no}_1_stat.xlsx')
# ans_stat.to_csv(f'data/contexts_{test_no}_2_stat.csv')

# %%
ans_stat.to_excel(f'data_out/test.xlsx')
